# %%
import numpy as np

# %%
q = np.array([[0, 1, 0, 1], [ 1, 1, 0, 1]])

# %%
q[np.array([True,False])]
# Out:
# array([[0, 1, 0, 1]])

# %%
np.array([0,1]).astype(bool)
# Out:
# array([False,  True])
